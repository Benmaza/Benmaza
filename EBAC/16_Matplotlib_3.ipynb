# %% [markdown]
# https://forum.easydatatransform.com/t/olympic-medals-table-csv/289

# %%
import numpy as np

# %%
import pandas as pd
df=pd.read_csv('olympic-medals.csv', index_col=0)
df
# Out:
#                             Gold  Silver  Bronze
# TEAM
# United States of America      39      41      33
# People's Republic of China    38      32      18
# Japan                         27      14      17
# Great Britain                 22      21      22
# ROC                           20      28      23
# ...                          ...     ...     ...
# Ghana                          0       0       1
# Grenada                        0       0       1
# Kuwait                         0       0       1
# Republic of Moldova            0       0       1
# Syrian Arab Republic           0       0       1
#
# [93 rows x 3 columns]

# %%
medallas = df.head(10)
medallas
# Out:
#                             Gold  Silver  Bronze
# TEAM
# United States of America      39      41      33
# People's Republic of China    38      32      18
# Japan                         27      14      17
# Great Britain                 22      21      22
# ROC                           20      28      23
# Australia                     17       7      22
# Netherlands                   10      12      14
# France                        10      12      11
# Germany                       10      11      16
# Italy                         10      10      20

# %%
# visualizacion de medallas Oro y PLata
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.bar(medallas.index, medallas['Gold'])
ax.set_xticklabels(medallas.index, rotation=90)
ax.set_ylabel('Número de medallas de Oro')
plt.show()
# Out:
# C:\Users\benma\AppData\Local\Temp\ipykernel_19064\1753127344.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(medallas.index, rotation=90)

# %%
fig, ax = plt.subplots()
ax.bar(medallas.index, medallas['Gold'])
ax.bar(medallas.index, medallas['Silver'], bottom=medallas['Gold'])
ax.bar(medallas.index, medallas['Bronze'], bottom=medallas['Gold']+medallas['Silver'])
ax.set_xticklabels(medallas.index, rotation=90)
ax.set_ylabel('Número de medallas de Oro')
ax.legend(['Oro', 'Plata', 'Bronce'])

plt.show()
# Out:
# C:\Users\benma\AppData\Local\Temp\ipykernel_19064\1557062177.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(medallas.index, rotation=90)

# %%
# creacion de histograma
fig, ax = plt.subplots()
ax.hist(df['Gold'])
plt.show()

# %%
# creacion de dos histograma en un solo grafico
fig, ax = plt.subplots()
ax.hist(df['Gold'], label='Oro')
ax.hist(df['Silver'], label='Plata')
ax.set_xlabel('Número de medallas')
ax.set_ylabel('Número Observaciones')
ax.legend()
plt.show()

# %%
# creacion de histogramas con especificaciones de intervalos / bins
fig, ax = plt.subplots()
ax.hist(df['Gold'], label='Oro', bins=[0,5,10,15,20,25,30,35,40], histtype='step')
ax.hist(df['Silver'], label='Plata', bins=[0,5,10,15,20,25,30,35,40], histtype='step')
ax.set_xlabel('Número de medallas')
ax.set_ylabel('Número Observaciones')
ax.legend()
plt.show()

# %%
# creacion de diagrama de caja
fig, ax = plt.subplots()
ax.boxplot([df['Gold'], df['Silver']])
ax.set_xticklabels(['Oro', 'Plata'])
ax.set_ylabel('Número de medallas')
plt.show()

# %%
# creacion de grafico de dispersion
fig, ax = plt.subplots()
ax.scatter(df['Gold'], df['Silver'])
ax.set_xlabel('Medallas de Oro')
ax.set_ylabel('Medallas de Plata')
plt.show()

# %%
# creacion de grafico de dispersion multiple con color
fig, ax = plt.subplots()
ax.scatter(df['Gold'], df['Silver'], color = 'red', label ='plata')
ax.scatter(df['Gold'], df['Bronze'], color = 'blue', label ='bronce')
ax.set_xlabel('Medallas de Oro')
ax.set_ylabel('Medallas de Plata')
ax.legend()
plt.show()

# %%
#creacion de grafico de dispersion con colores degradados
fig, ax = plt.subplots()
# Genera una secuencia de números para usar en el degradado de color
colors = np.arange(len(df))
scatter = ax.scatter(df['Gold'], df['Silver'], c=colors, cmap='viridis')
ax.set_xlabel('Medallas de Oro')
ax.set_ylabel('Medallas de Plata')
# Añade una barra de color para indicar qué significa cada color
fig.colorbar(scatter)
plt.show()
