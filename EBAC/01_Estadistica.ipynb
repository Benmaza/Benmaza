# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('gapminder.csv')
df
# Out:
#          geo  time  adults_with_hiv_percent_age_15_49  \
# 0        afg  1700                                NaN
# 1        afg  1800                                NaN
# 2        afg  1801                                NaN
# 3        afg  1802                                NaN
# 4        afg  1803                                NaN
# ...      ...   ...                                ...
# 79304  world  2026                                NaN
# 79305  world  2027                                NaN
# 79306  world  2028                                NaN
# 79307  world  2029                                NaN
# 79308  world  2030                                NaN
#
#        age_at_1st_marriage_women  aged_15_24_employment_rate_percent  \
# 0                            NaN                                 NaN
# 1                            NaN                                 NaN
# 2                            NaN                                 NaN
# 3                            NaN                                 NaN
# 4                            NaN                                 NaN
# ...                          ...                                 ...
# 79304                        NaN                                 NaN
# 79305                        NaN                                 NaN
# 79306                        NaN                                 NaN
# 79307                        NaN                                 NaN
# 79308                        NaN                                 NaN
#
#        aged_15_24_unemployment_rate_percent  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 79304                                   NaN
# 79305                                   NaN
# 79306                                   NaN
# 79307                                   NaN
# 79308                                   NaN
#
#        aged_15_64_labour_force_participation_rate_percent  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 79304                                                NaN
# 79305                                                NaN
# 79306                                                NaN
# 79307                                                NaN
# 79308                                                NaN
#
#        aged_15plus_employment_rate_percent  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 79304                                  NaN
# 79305                                  NaN
# 79306                                  NaN
# 79307                                  NaN
# 79308                                  NaN
#
#        aged_15plus_labour_force_participation_rate_percent  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 79304                                                NaN
# 79305                                                NaN
# 79306                                                NaN
# 79307                                                NaN
# 79308                                                NaN
#
#        aged_15plus_unemployment_rate_percent  ...  underweight_children  \
# 0                                        NaN  ...                   NaN
# 1                                        NaN  ...                   NaN
# 2                                        NaN  ...                   NaN
# 3                                        NaN  ...                   NaN
# 4                                        NaN  ...                   NaN
# ...                                      ...  ...                   ...
# 79304                                    NaN  ...                   NaN
# 79305                                    NaN  ...                   NaN
# 79306                                    NaN  ...                   NaN
# 79307                                    NaN  ...                   NaN
# 79308                                    NaN  ...                   NaN
#
#        urban_population  urban_population_growth_annual_percent  \
# 0                   NaN                                     NaN
# 1                   NaN                                     NaN
# 2                   NaN                                     NaN
# 3                   NaN                                     NaN
# 4                   NaN                                     NaN
# ...                 ...                                     ...
# 79304               NaN                                     NaN
# 79305               NaN                                     NaN
# 79306               NaN                                     NaN
# 79307               NaN                                     NaN
# 79308               NaN                                     NaN
#
#        urban_population_percent_of_total  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ...                                  ...
# 79304                                NaN
# 79305                                NaN
# 79306                                NaN
# 79307                                NaN
# 79308                                NaN
#
#        urban_poverty_percent_urban_people_below_national_urban  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 79304                                                NaN
# 79305                                                NaN
# 79306                                                NaN
# 79307                                                NaN
# 79308                                                NaN
#
#        water_and_sanitation_aid_given_percent_of_aid  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 79304                                            NaN
# 79305                                            NaN
# 79306                                            NaN
# 79307                                            NaN
# 79308                                            NaN
#
#        water_withdrawal_cu_meters_per_person  wood_removal_cubic_meters  \
# 0                                        NaN                        NaN
# 1                                        NaN                        NaN
# 2                                        NaN                        NaN
# 3                                        NaN                        NaN
# 4                                        NaN                        NaN
# ...                                      ...                        ...
# 79304                                    NaN                        NaN
# 79305                                    NaN                        NaN
# 79306                                    NaN                        NaN
# 79307                                    NaN                        NaN
# 79308                                    NaN                        NaN
#
#        working_hours_per_week  yearly_co2_emissions_1000_tonnes
# 0                         NaN                               NaN
# 1                         NaN                               NaN
# 2                         NaN                               NaN
# 3                         NaN                               NaN
# 4                         NaN                               NaN
# ...                       ...                               ...
# 79304                     NaN                               NaN
# 79305                     NaN                               NaN
# 79306                     NaN                               NaN
# 79307                     NaN                               NaN
# 79308                     NaN                               NaN
#
# [79309 rows x 537 columns]
