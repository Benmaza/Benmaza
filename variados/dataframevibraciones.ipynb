# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=np.array([['20201123',	'0.18',	'0.16',	'0.21',	'0.24',	'0.25',	'0.19',	'0.19',	'0.12',	'0.2',	'0.19',	'0.06',	'0.18'],
               ['20210520',	'0.016','0.19',	'0.23',	'0.23',	'0.23',	'0.25',	'0.18',	'0.08',	'0.16',	'0.15',	'0.07',	'0.16'],
               ['20211119',	'0.16',	'0.13',	'0.19',	'0.18',	'0.18',	'0.23',	'0.13',	'0.06',	'0.11',	'0.11',	'0.05',	'0.11'],
               ['20221201',	'0.18',	'0.28',	'0.26',	'0.25',	'0.27',	'0.24',	'0.16',	'0.08',	'0.14',	'0.14',	'0.07',	'0.18'],
               ['20230518',	'0.19',	'0.22',	'0.20',	'0.25',	'0.21',	'0.25',	'0.16',	'0.09',	'0.13',	'0.16',	'0.04',	'0.15'],
               ['20230712',	'0.14',	'0.20',	'0.28',	'0.26',	'0.26',	'0.16',	'0.21',	'0.07',	'0.20',	'0.17',	'0.06',	'0.18'],
               ['20231219',	'0.17',	'0.19',	'0.16',	'0.24',	'0.27',	'0.18',	'0.18',	'0.10',	'0.16',	'0.13',	'0.09',	'0.17'],
               ['20240127',	'0.14',	'0.17',	'0.18',	'0.25',	'0.22',	'0.2',	'0.16',	'0.08',	'0.18',	'0.14',	'0.06',	'0.19'],
               ['20240213',	'0.12',	'0.16',	'0.19',	'0.21',	'0.19',	'0.19',	'0.18',	'0.06',	'0.18',	'0.15',	'0.05',	'0.13'],
              ])
data
# Out:
# array([['20201123', '0.18', '0.16', '0.21', '0.24', '0.25', '0.19',
#         '0.19', '0.12', '0.2', '0.19', '0.06', '0.18'],
#        ['20210520', '0.016', '0.19', '0.23', '0.23', '0.23', '0.25',
#         '0.18', '0.08', '0.16', '0.15', '0.07', '0.16'],
#        ['20211119', '0.16', '0.13', '0.19', '0.18', '0.18', '0.23',
#         '0.13', '0.06', '0.11', '0.11', '0.05', '0.11'],
#        ['20221201', '0.18', '0.28', '0.26', '0.25', '0.27', '0.24',
#         '0.16', '0.08', '0.14', '0.14', '0.07', '0.18'],
#        ['20230518', '0.19', '0.22', '0.20', '0.25', '0.21', '0.25',
#         '0.16', '0.09', '0.13', '0.16', '0.04', '0.15'],
#        ['20230712', '0.14', '0.20', '0.28', '0.26', '0.26', '0.16',
#         '0.21', '0.07', '0.20', '0.17', '0.06', '0.18'],
#        ['20231219', '0.17', '0.19', '0.16', '0.24', '0.27', '0.18',
#         '0.18', '0.10', '0.16', '0.13', '0.09', '0.17'],
#        ['20240127', '0.14', '0.17', '0.18', '0.25', '0.22', '0.2',
# ...

# %%
df=pd.DataFrame(data, columns=['Fecha',	'AHV',	'AVV',	'AAV',	'BHV',	'BVV',	'BAV',	'CHV',	'CVV',	'CAV',	'DHV',	'DVV',	'DAV'])
df['Fecha']=df['Fecha'].astype('datetime64[us]')
df['Fecha']=pd.to_datetime(df['Fecha'], format='%YY%mm%dd')
df['AHV']=df['AHV'].astype('float')
df['AVV']=df['AVV'].astype('float')
df['AAV']=df['AAV'].astype('float')
df['BHV']=df['BHV'].astype('float')
df['BVV']=df['BVV'].astype('float')
df['BAV']=df['BAV'].astype('float')
df['CHV']=df['CHV'].astype('float')
df['CVV']=df['CVV'].astype('float')
df['CAV']=df['CAV'].astype('float')
df['DHV']=df['DHV'].astype('float')
df['DVV']=df['DVV'].astype('float')
df['DAV']=df['DAV'].astype('float')
df
# Out:
#        Fecha    AHV   AVV   AAV   BHV   BVV   BAV   CHV   CVV   CAV   DHV  \
# 0 2020-11-23  0.180  0.16  0.21  0.24  0.25  0.19  0.19  0.12  0.20  0.19
# 1 2021-05-20  0.016  0.19  0.23  0.23  0.23  0.25  0.18  0.08  0.16  0.15
# 2 2021-11-19  0.160  0.13  0.19  0.18  0.18  0.23  0.13  0.06  0.11  0.11
# 3 2022-12-01  0.180  0.28  0.26  0.25  0.27  0.24  0.16  0.08  0.14  0.14
# 4 2023-05-18  0.190  0.22  0.20  0.25  0.21  0.25  0.16  0.09  0.13  0.16
# 5 2023-07-12  0.140  0.20  0.28  0.26  0.26  0.16  0.21  0.07  0.20  0.17
# 6 2023-12-19  0.170  0.19  0.16  0.24  0.27  0.18  0.18  0.10  0.16  0.13
# 7 2024-01-27  0.140  0.17  0.18  0.25  0.22  0.20  0.16  0.08  0.18  0.14
# 8 2024-02-13  0.120  0.16  0.19  0.21  0.19  0.19  0.18  0.06  0.18  0.15
#
#     DVV   DAV
# 0  0.06  0.18
# 1  0.07  0.16
# 2  0.05  0.11
# 3  0.07  0.18
# 4  0.04  0.15
# 5  0.06  0.18
# 6  0.09  0.17
# 7  0.06  0.19
# 8  0.05  0.13

# %%
# Generar un gráfico de líneas para cada columna
plt.figure(figsize=(20, 10))
plt.title('Gráficos de líneas para cada columna')

sns.lineplot(x='Fecha', y='AHV', data=df, label='AHV')
sns.lineplot(x='Fecha', y='AVV', data=df, label='AVV')
sns.lineplot(x='Fecha', y='AAV', data=df, label='AAV')
sns.lineplot(x='Fecha', y='BHV', data=df, label='BHV')
sns.lineplot(x='Fecha', y='BVV', data=df, label='BVV')
sns.lineplot(x='Fecha', y='BAV', data=df, label='BAV')
sns.lineplot(x='Fecha', y='CHV', data=df, label='CHV')
sns.lineplot(x='Fecha', y='CVV', data=df, label='CVV')
sns.lineplot(x='Fecha', y='CAV', data=df, label='CAV')
sns.lineplot(x='Fecha', y='DHV', data=df, label='DHV')
sns.lineplot(x='Fecha', y='DVV', data=df, label='DVV')
sns.lineplot(x='Fecha', y='DAV', data=df, label='DAV')

plt.xticks(rotation=90)  # Rotar las etiquetas del eje x en vertical


plt.legend()
plt.show()
