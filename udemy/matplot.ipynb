# %% [markdown]
# ## crear un vector y representarlo en una grafica

# %%
import matplotlib.pyplot as plt
import numpy as np

myarray = np.array([1, 2, 3,])
plt.plot(myarray)
plt.xlabel('Eje X')
plt.show()
